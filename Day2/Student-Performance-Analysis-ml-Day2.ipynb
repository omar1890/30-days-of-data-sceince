# %% [markdown]
# <img src="Data/student performance.png" style='width:700;height:600;'>

# %%
import pandas as pd 
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import dabl
# Out:
# C:\Users\Omar Wael\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = pd.read_csv('Data/StudentsPerformance.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#check unique values for categorical columns
data.select_dtypes('object').nunique()
# Out:
# gender                         2
# race/ethnicity                 5
# parental level of education    6
# lunch                          2
# test preparation course        2
# dtype: int64

# %%
#check null values
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize'] = (18,6)
plt.style.use('fivethirtyeight')
dabl.plot(data,target_col='math score')
# Out:
# Target looks like regression
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# ...

# %%
plt.rcParams['figure.figsize'] = (18,6)
plt.style.use('fivethirtyeight')
dabl.plot(data,target_col='reading score')
# Out:
# Target looks like regression
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# C:\Users\Omar Wael\Anaconda3\lib\site-packages\dabl\plot\utils.py:376: UserWarning: FixedFormatter should only be used together with FixedLocator
#   for t in ax.get_xticklabels()]
# ...

# %% [markdown]
# ## Lets check the Effect of Lunch on Student’s Performnce

# %%
data[['lunch','gender','math score','writing score','reading score']].groupby(['lunch']).agg('median')
# Out:
#               math score  writing score  reading score
# lunch
# free/reduced        60.0           64.0           65.0
# standard            69.0           72.0           72.0

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
data[['test preparation course','math score', 'reading score','writing score']].groupby('test preparation course').agg('median')
# Out:
#                          math score  reading score  writing score
# test preparation course
# completed                      69.0           75.0           76.0
# none                           64.0           67.0           65.0

# %%
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (15,5)
sns.countplot(data['gender'],palette='bone')
plt.title('Comparison of Males and Females', fontweight = 30)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('ggplot')
sns.countplot(data['race/ethnicity'], palette = 'pink')
plt.title('Comparison of various groups', fontweight = 30, fontsize = 20)
plt.xlabel('Groups')
plt.ylabel('count')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (15, 9)
plt.style.use('tableau-colorblind10')

sns.countplot(data['math score'], palette = 'BuPu')
plt.title('Comparison of math scores', fontweight = 30, fontsize = 20)
plt.xlabel('score')
plt.ylabel('count')
plt.xticks(rotation = 90)
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

data['total_score'] = data['math score'] + data['reading score'] + data['writing score']

sns.distplot(data['total_score'], color = 'magenta')

plt.title('comparison of total score of all the students', fontweight = 30, fontsize = 20)
plt.xlabel('total score scored by the students')
plt.ylabel('count')
plt.show()

# %%
data['percentage'] = data['total_score']/3
sns.distplot(data['percentage'], color = 'magenta')

plt.title('comparison of total score of all the students', fontweight = 30, fontsize = 20)
plt.xlabel('percentage score scored by the students')
plt.ylabel('count')
plt.show()

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score', 'total_score', 'percentage'],
#       dtype='object')

# %%
def getgrade(percentage):
    if percentage >= 90:
        return 'O'
    elif percentage <90 and percentage >= 80:
        return 'A'
    elif percentage < 80 and percentage >= 70:
        return 'B'
    elif percentage < 70 and percentage >= 60:
        return 'C'
    else:
        return 'D'

# %%
data['grades'] = data.apply(lambda x:getgrade(x['percentage']),axis='columns')
data['grades']
# Out:
# 0      B
# 1      A
# 2      O
# 3      D
# 4      B
#       ..
# 995    O
# 996    D
# 997    C
# 998    B
# 999    A
# Name: grades, Length: 1000, dtype: object

# %%
data.select_dtypes('object')
# Out:
#      gender race/ethnicity grades
# 0    female        group B      B
# 1    female        group C      A
# 2    female        group B      O
# 3      male        group A      D
# 4      male        group C      B
# ..      ...            ...    ...
# 995  female        group E      O
# 996    male        group C      D
# 997  female        group C      C
# 998  female        group D      B
# 999  female        group D      A
#
# [1000 rows x 3 columns]

# %% [markdown]
# # Labeling

# %%
cat_columns = data.select_dtypes('object')
cat_columns
# Out:
#     grades
# 0        B
# 1        A
# 2        O
# 3        D
# 4        B
# ..     ...
# 995      O
# 996      D
# 997      C
# 998      B
# 999      A
#
# [1000 rows x 1 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df = data
df['lunch']=le.fit_transform(df['lunch'])
df['test preparation course']=le.fit_transform(df['test preparation course'])
df['parental level of education']=le.fit_transform(df['parental level of education'])
df['gender']=le.fit_transform(df['gender'])
df['race/ethnicity'] = df['race/ethnicity'].replace('group A', 1)
df['race/ethnicity'] = df['race/ethnicity'].replace('group B', 2)
df['race/ethnicity'] = df['race/ethnicity'].replace('group C', 3)
df['race/ethnicity'] = df['race/ethnicity'].replace('group D', 4)
df['race/ethnicity'] = df['race/ethnicity'].replace('group E', 5)

df
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         0               2                            1      1
# 1         0               3                            4      1
# 2         0               2                            3      1
# 3         1               1                            0      0
# 4         1               3                            4      1
# ..      ...             ...                          ...    ...
# 995       0               5                            3      1
# 996       1               3                            2      0
# 997       0               3                            2      0
# 998       0               4                            4      1
# 999       0               4                            4      0
#
#      test preparation course  math score  reading score  writing score  \
# 0                          1          72             72             74
# ...

# %%
data['grades'].value_counts()
# Out:
# D    285
# B    261
# C    256
# A    146
# O     52
# Name: grades, dtype: int64

# %%
X = df.iloc[:,:10]
y = df.iloc[:,10]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test , y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=42)

print(X_train.shape,X_test.shape)
# Out:
# (750, 10) (250, 10)

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler 

mm = MinMaxScaler()

X_train = mm.fit_transform(X_train)
X_test = mm.fit_transform(X_test)
X_train.shape
# Out:
# (750, 10)

# %% [markdown]
# # Applying PCA

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=None)

X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)

explained_variance = pca.explained_variance_ratio_
print(explained_variance)

pca = PCA(n_components=2)

X_train = pca.fit_transform(X_train)
X_test = pca.fit_transform(X_test)
# Out:
# [2.53935802e-01 2.46963611e-01 2.05995240e-01 1.25583915e-01
#  9.82242154e-02 6.61181467e-02 2.00170182e-03 1.17736726e-03
#  8.54368833e-33 1.62737904e-33]

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train,y_train)

y_pred = model.predict(X_test)

print('Training Accuracy ', model.score(X_train,y_train))
print('Testing Accuracy ', model.score(X_test,y_test))
# Out:
# Training Accuracy  0.45866666666666667
# Testing Accuracy  0.468

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# creating a model
model = RandomForestClassifier()

# feeding the training data to the model
model.fit(X_train, y_train)

# predicting the x-test results
y_pred = model.predict(X_test)

# calculating the accuracies
print("Training Accuracy :", model.score(X_train, y_train))
print("Testing Accuracy :", model.score(X_test, y_test))
# Out:
# Training Accuracy : 1.0
# Testing Accuracy : 0.284

# %% [markdown]
# # END
